# %%
from data_infotbc import *

# %%
df_list = get_data()
# Out:
# INFO:scrapy.utils.log:Scrapy 1.0.3 started (bot: ScrapInfotbc)
# INFO:scrapy.utils.log:Optional features available: ssl, http11
# INFO:scrapy.utils.log:Overridden settings: {'NEWSPIDER_MODULE': 'ScrapInfotbc.spiders', 'SPIDER_MODULES': ['ScrapInfotbc.spiders'], 'LOG_FILE': 'scrapy_log', 'BOT_NAME': 'ScrapInfotbc'}
# WARNING:py.warnings::0: UserWarning: You do not have a working installation of the service_identity module: 'No module named service_identity'.  Please install it from <https://pypi.python.org/pypi/service_identity> and make sure all of its dependencies are satisfied.  Without the service_identity module and a recent enough pyOpenSSL to support it, Twisted can perform only rudimentary TLS client hostname verification.  Many valid certificate/hostname mappings may be rejected.
#
# INFO:scrapy.middleware:Enabled extensions: CloseSpider, TelnetConsole, LogStats, CoreStats, SpiderState
# ...

# %%
df_list['infotbc']
# Out:
#                                                links  \
# 0  /alertes/batcub-interruption-du-parcours-stali...
#
#                                             messages  \
# 0  BatCub : Interruption du parcours Stalingrad >...
#
#                                             contents
# 0  [Cette information est mise à jour en temps ré...

# %%
df_list['mobilinfotbc']
# Out:
#                                                 links  \
# 0                         /alertes/marche-de-merignac
# 1                         /alertes/marche-de-merignac
# 2   /alertes/pole-dechanges-gambetta-creation-dun-...
# 3   /alertes/pole-dechanges-gambetta-creation-dun-...
# 4   /alertes/pole-dechanges-gambetta-creation-dun-...
# 5          /alertes/pessac-travaux-avenue-jean-jaures
# 6   /alertes/villenave-dornon-travaux-route-de-tou...
# 7   /alertes/villenave-dornon-travaux-route-de-tou...
# 8   /alertes/villenave-dornon-travaux-route-de-tou...
# 9        /alertes/bordeaux-fermeture-rue-ulysse-gayon
# 10  /alertes/villenave-dornon-travaux-rond-point-d...
# 11  /alertes/blanquefort-travaux-avenue-du-general...
# 12  /alertes/blanquefort-travaux-avenue-du-general...
# 13  /alertes/blanquefort-travaux-avenue-du-general...
# 14  /alertes/batcub-interruption-du-parcours-stali...
# 15       /alertes/bordeaux-travaux-rue-lucien-faure-0
# ...

# %%
read_dict("data_mobilinfotbc")
# Out:
#                                                 links  \
# 0   /alertes/levee-du-pont-chaban-delmas-la-nuit-d...
# 1             /alertes/match-au-nouveau-stade-le-3101
# 2                         /alertes/marche-de-merignac
# 3   /alertes/pole-dechanges-gambetta-creation-dun-...
# 4   /alertes/pole-dechanges-gambetta-creation-dun-...
# 5          /alertes/pessac-travaux-avenue-jean-jaures
# 6   /alertes/villenave-dornon-travaux-route-de-tou...
# 7        /alertes/bordeaux-fermeture-rue-ulysse-gayon
# 8   /alertes/villenave-dornon-travaux-rond-point-d...
# 9   /alertes/blanquefort-travaux-avenue-du-general...
# 10       /alertes/bordeaux-travaux-rue-lucien-faure-0
# 11  /alertes/levee-du-pont-chaban-delmas-la-nuit-d...
# 12                         /alertes/marche-de-bassens
# 13  /alertes/levee-du-pont-chaban-delmas-modificat...
# 14  /alertes/pessac-travaux-rond-point-la-paillere...
# 15                 /alertes/match-stade-chaban-delmas
# ...

# %%
df = read_dict("data_infotbc")

# %%
df
# Out:
#                                                links  \
# 0  /alertes/batcub-interruption-du-parcours-stali...
# 0  /alertes/batcub-interruption-du-parcours-stali...
#
#                                             messages
# 0  BatCub : Interruption du parcours Stalingrad >...
# 0  BatCub : Interruption du parcours Stalingrad >...

# %%
df1 = read_dict("data_infotbc_link")

# %%
df1
# Out:
#                                             contents
# 0  [Cette information est mise à jour en temps ré...
